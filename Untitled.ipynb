# %%
conda create -n qenv python=3.10 -y
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\soura\anaconda3\envs\qenv
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h2bbff1b_6          90 KB
#     ca-certificates-2025.12.2  |       haa95532_0         125 KB
#     expat-2.7.3                |       h885b0b7_3          31 KB
#     libexpat-2.7.3             |       h885b0b7_3         119 KB
#     libffi-3.4.4               |       hd77b12b_1         122 KB
#     libzlib-1.3.1              |       h02ab6af_0          64 KB
#     openssl-3.0.18             |       h543e019_0         6.8 MB
#     pip-25.3                   |     pyhc872135_0         1.1 MB
#     python-3.10.19             |       h981015d_0        15.3 MB
# ...

# %%
conda activate qenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install numpy==1.24.4 pandas==1.5.3
# !pip install cirq-core==1.3.0 qsimcirq==0.21.0
# !pip install node2vec==0.5.0 pyfume==0.3.4
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\soura\\anaconda3\\Lib\\site-packages\\~0mpy.libs\\libscipy_openblas64_-9e3e5a4229c1ca39f10dc82bba9e2b2b.dll'
# Consider using the `--user` option or check the permissions.
#   Using cached numpy-1.24.4-cp311-cp311-win_amd64.whl (14.8 MB)
# ...
#                                               0.0/10.3 MB ? eta -:--:--
#      -                                        0.3/10.3 MB 7.0 MB/s eta 0:00:02
#      --                                       0.7/10.3 MB 7.3 MB/s eta 0:00:02
#      ----                                     1.1/10.3 MB 7.8 MB/s eta 0:00:02
#      -----                                    1.5/10.3 MB 8.0 MB/s eta 0:00:02
#      -------                                  1.8/10.3 MB 7.7 MB/s eta 0:00:02
#      --------                                 2.3/10.3 MB 8.2 MB/s eta 0:00:01
#      -----------                              2.8/10.3 MB 8.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~\anaconda3\Lib\site-packages\pandas\compat\__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
# ...
